# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dataset = pd.read_csv(r"C:\Users\KIIT\Desktop\project\ml\Algerian_forest_fires_dataset_UPDATE.csv",header=1)

# %%
dataset.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
# dtypes: object(14)
# memory usage: 27.0+ KB

# %% [markdown]
# ## Data cleaning

# %%
## Checking for missing values
dataset[dataset.isnull().any(axis=1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 122  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 167                             14    07  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes
# 122   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 167  88.9  12.9  14.6 9  12.5  10.4  fire          NaN

# %%
df = dataset

# %%
df .loc[:122,"Region"] = 0
df.loc[122:,"Region"] = 1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
#  14  Region       246 non-null    float64
# dtypes: float64(1), object(14)
# memory usage: 29.0+ KB

# %%
df[['Region']] = df[['Region']].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
#  14  Region       246 non-null    int32
# dtypes: int32(1), object(14)
# memory usage: 28.0+ KB

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes    Region
# 0  not fire          0
# 1  not fire          0
# 2  not fire          0
# 3  not fire          0
# 4  not fire          0

# %%
df.tail()
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 241  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 242  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 243  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 244  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 245  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes    Region
# 241  6.5       fire          1
# 242    0   not fire          1
# 243  0.2   not fire          1
# 244  0.7   not fire          1
# 245  0.5  not fire           1

# %%
df.isnull().sum()
# Out:
# day            0
# month          1
# year           1
# Temperature    1
#  RH            1
#  Ws            1
# Rain           1
# FFMC           1
# DMC            1
# DC             1
# ISI            1
# BUI            1
# FWI            1
# Classes        2
# Region         0
# dtype: int64

# %%
## removing all the Null value 

df = df.dropna().reset_index(drop=True)

# %%
df.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
#  RH            0
#  Ws            0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# Region         0
# dtype: int64

# %%
df.iloc[[122]]
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI  \
# 122  day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI
#
#      FWI  Classes    Region
# 122  FWI  Classes         1

# %%
df= df.drop(122).reset_index(drop=True)

# %%
df.iloc[[122]]
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC   DC  ISI  BUI  FWI  \
# 122  01    06  2012          32  71  12   0.7  57.1  2.5  8.2  0.6  2.8  0.2
#
#        Classes    Region
# 122  not fire          1

# %%
df.iloc[[122]]
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC   DC  ISI  BUI  FWI  \
# 122  01    06  2012          32  71  12   0.7  57.1  2.5  8.2  0.6  2.8  0.2
#
#        Classes    Region
# 122  not fire          1

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  ', 'Region'],
#       dtype='object')

# %%
## fix spaces in column names   classes
df.columns = df.columns.str.strip()

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    object
#  1   month        243 non-null    object
#  2   year         243 non-null    object
#  3   Temperature  243 non-null    object
#  4   RH           243 non-null    object
#  5   Ws           243 non-null    object
#  6   Rain         243 non-null    object
#  7   FFMC         243 non-null    object
#  8   DMC          243 non-null    object
#  9   DC           243 non-null    object
#  10  ISI          243 non-null    object
#  11  BUI          243 non-null    object
#  12  FWI          243 non-null    object
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int32
# dtypes: int32(1), object(14)
# memory usage: 27.7+ KB

# %% [markdown]
# ## change the required columns as integer type

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
df[['day','month','year','Temperature','RH','Ws']] = df[['day','month','year','Temperature','RH','Ws']].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int32
#  1   month        243 non-null    int32
#  2   year         243 non-null    int32
#  3   Temperature  243 non-null    int32
#  4   RH           243 non-null    int32
#  5   Ws           243 non-null    int32
#  6   Rain         243 non-null    object
#  7   FFMC         243 non-null    object
#  8   DMC          243 non-null    object
#  9   DC           243 non-null    object
#  10  ISI          243 non-null    object
#  11  BUI          243 non-null    object
#  12  FWI          243 non-null    object
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int32
# dtypes: int32(7), object(8)
# memory usage: 22.0+ KB

# %%
df[['Rain','FFMC','DMC','DC','ISI','BUI','FWI']] = df[['Rain','FFMC','DMC','DC','ISI','BUI','FWI']].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int32
#  1   month        243 non-null    int32
#  2   year         243 non-null    int32
#  3   Temperature  243 non-null    int32
#  4   RH           243 non-null    int32
#  5   Ws           243 non-null    int32
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int32
# dtypes: float64(7), int32(7), object(1)
# memory usage: 22.0+ KB

# %%
df.describe()
# Out:
#               day       month    year  Temperature          RH          Ws  \
# count  243.000000  243.000000   243.0   243.000000  243.000000  243.000000
# mean    15.761317    7.502058  2012.0    32.152263   62.041152   15.493827
# std      8.842552    1.114793     0.0     3.628039   14.828160    2.811385
# min      1.000000    6.000000  2012.0    22.000000   21.000000    6.000000
# 25%      8.000000    7.000000  2012.0    30.000000   52.500000   14.000000
# 50%     16.000000    8.000000  2012.0    32.000000   63.000000   15.000000
# 75%     23.000000    8.000000  2012.0    35.000000   73.500000   17.000000
# max     31.000000    9.000000  2012.0    42.000000   90.000000   29.000000
#
#              Rain        FFMC         DMC          DC         ISI         BUI  \
# count  243.000000  243.000000  243.000000  243.000000  243.000000  243.000000
# mean     0.762963   77.842387   14.680658   49.430864    4.742387   16.690535
# ...

# %% [markdown]
# ## save the cleaned dataset

# %%
# Save the cleaned dataset to a new file
df.to_csv(r"C:\Users\KIIT\Desktop\project\ml\Algerian_forest_fires_cleaned_dataset_v2.csv", index=False)

# %% [markdown]
# ## EDA

# %%
df_copy=df

# %%
df_copy.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes  Region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3  0.0  not fire          0
# 4  0.5  not fire          0

# %%
df_copy=df_copy.drop(['day','month','year'],axis=1)

# %%
df_copy.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI      Classes  \
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5  not fire
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4  not fire
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1  not fire
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0  not fire
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5  not fire
#
#    Region
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df_copy['Classes'].value_counts()
# Out:
# Classes
# fire             131
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: count, dtype: int64

# %%
## do the  encoding of the features of classes

df_copy['Classes'] = np.where(df_copy['Classes'].str.contains('not fire'),0,1)

# %%
df_copy.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0       0

# %%
df_copy['Classes'].value_counts()
# Out:
# Classes
# 1    137
# 0    106
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Apply seaborn style
plt.style.use('ggplot')  # Use a valid style from 
# plt.style.available
# print(plt.style.available)
# df_copy.plot (kind="kde", figsize=(20, 10), subplots=True, layout=(4, 3), sharex=False)
df_copy.hist(bins=50,figsize=(20,15))

plt.show()

# %%
## percentage of fire and not fire
percentage=df_copy['Classes'].value_counts(normalize=True)*100

# %%
classlabels = ['Fire','Not Fire']
plt.Figure(figsize=(22,10))
plt.pie(percentage,labels=classlabels,autopct='%1.1f%%')
plt.title("pie chart of classes")
plt.show()

# %%
## correlation

df_copy.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.651400 -0.284510 -0.326492  0.676568  0.485687
# RH             -0.651400  1.000000  0.244048  0.222356 -0.644873 -0.408519
# Ws             -0.284510  0.244048  1.000000  0.171506 -0.166548 -0.000721
# Rain           -0.326492  0.222356  0.171506  1.000000 -0.543906 -0.288773
# FFMC            0.676568 -0.644873 -0.166548 -0.543906  1.000000  0.603608
# DMC             0.485687 -0.408519 -0.000721 -0.288773  0.603608  1.000000
# DC              0.376284 -0.226941  0.079135 -0.298023  0.507397  0.875925
# ISI             0.603871 -0.686667  0.008532 -0.347484  0.740007  0.680454
# BUI             0.459789 -0.353841  0.031438 -0.299852  0.592011  0.982248
# FWI             0.566670 -0.580957  0.032368 -0.324422  0.691132  0.875864
# Classes         0.516015 -0.432161 -0.069964 -0.379097  0.769492  0.585658
# ...

# %%
sns.heatmap(df_copy.corr(),annot=True)
plt.figure(figsize=(10,6))
plt.show()

# %%
## box plot
sns.boxplot(df_copy['FWI'],color='green')
plt.show()

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes  Region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3  0.0  not fire          0
# 4  0.5  not fire          0

# %%
df['Classes']=df['Classes']=np.where(df['Classes'].str.contains('not fire'),'not fire','fire')

# %% [markdown]
# ## Bejaia Region

# %%
## monthly fire analysis                                 
plt.close('all')
dftemp = df.loc[df['Region']==1]
plt.subplots(figsize=(13,6))
sns.set_style('whitegrid')
sns.countplot(x='month',hue='Classes',data=df)
plt.ylabel('Number of fires',weight='bold')
plt.xlabel('Months',weight='bold')
plt.title("Fire Analysis of Bejaia Region",weight='bold')
plt.show()

# %% [markdown]
# ## Sidi-Bel Abbes Region

# %%
## monthly fire analysis
plt.close('all')
dftemp = df.loc[df['Region']==0]
plt.subplots(figsize=(13,6))
sns.set_style('whitegrid')
sns.countplot(x='month',hue='Classes',data=df)
plt.ylabel('Number of fires',weight='bold')
plt.xlabel('Months',weight='bold')
plt.title("Fire Analysis of Sidi-Bel Abbes Region",weight='bold')
plt.show()

# %% [markdown]
# ## Model Training

# %%
df = pd.read_csv(r"C:\Users\KIIT\Desktop\project\ml\Algerian_forest_fires_cleaned_dataset_v2.csv")

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes  Region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3  0.0  not fire          0
# 4  0.5  not fire          0

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
df.drop(['day','month','year'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI      Classes  \
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5  not fire
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4  not fire
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1  not fire
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0  not fire
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5  not fire
#
#    Region
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df['Classes'].value_counts()
# Out:
# Classes
# fire             131
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: count, dtype: int64

# %%
df['Classes']=np.where(df['Classes'].str.contains('not fire'),0,1)

# %%
df['Classes'].value_counts()
# Out:
# Classes
# 1    137
# 0    106
# Name: count, dtype: int64

# %%
## independent and dependent variable

x= df.drop('FWI',axis=1)
y=df['FWI']

# %%
x
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  Classes  Region
# 0             29  57  18   0.0  65.7   3.4   7.6  1.3   3.4        0       0
# 1             29  61  13   1.3  64.4   4.1   7.6  1.0   3.9        0       0
# 2             26  82  22  13.1  47.1   2.5   7.1  0.3   2.7        0       0
# 3             25  89  13   2.5  28.6   1.3   6.9  0.0   1.7        0       0
# 4             27  77  16   0.0  64.8   3.0  14.2  1.2   3.9        0       0
# ..           ...  ..  ..   ...   ...   ...   ...  ...   ...      ...     ...
# 238           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9        1       1
# 239           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2        0       1
# 240           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4        0       1
# 241           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1        0       1
# 242           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8        0       1
#
# [243 rows x 11 columns]

# %%
y
# Out:
# 0      0.5
# 1      0.4
# 2      0.1
# 3      0.0
# 4      0.5
#       ...
# 238    6.5
# 239    0.0
# 240    0.2
# 241    0.7
# 242    0.5
# Name: FWI, Length: 243, dtype: float64

# %%
## train test split

from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test= train_test_split(x,y,test_size=0.25,random_state=42)

# %%
X_train.shape,X_test.shape
# Out:
# ((182, 11), (61, 11))

# %%
## check multicollinearity
plt.close("all")
plt.figure(figsize=(12,10))
corr=X_train.corr()
sns.heatmap(corr,annot=True)
plt.show()

# %%
def correlation(dataset,threshold):
    col_corr= set()

    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i,j]>threshold):
                colname=corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
corr_features=correlation(X_train,0.85)
corr_features
# Out:
# {'BUI', 'DC'}

# %%
X_train
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC   ISI   BUI  Classes  Region
# 97            29  74  19   0.1  75.8   3.6  32.2   2.1   5.6        0       0
# 141           31  72  14   0.2  60.2   3.8   8.0   0.8   3.7        0       1
# 192           40  31  15   0.0  94.2  22.5  46.3  16.6  22.4        1       1
# 68            32  60  18   0.3  77.1  11.3  47.0   2.2  14.1        0       0
# 119           32  47  14   0.7  77.5   7.1   8.8   1.8   6.8        0       0
# ..           ...  ..  ..   ...   ...   ...   ...   ...   ...      ...     ...
# 106           24  82  15   0.4  44.9   0.9   7.3   0.2   1.4        0       0
# 14            28  80  17   3.1  49.4   3.0   7.4   0.4   3.0        0       0
# 92            25  76  17   7.2  46.0   1.3   7.5   0.2   1.8        0       0
# 179           34  59  16   0.0  88.1  19.5  47.2   7.4  19.5        1       1
# 102           30  77  21   1.8  58.5   1.9   8.4   1.1   2.4        0       0
#
# [182 rows x 11 columns]

# %%
## drop features when correlation is more than 0.85
X_train.drop(corr_features,axis=1,inplace=True)
X_test.drop(corr_features,axis=1,inplace=True)
X_train.shape,X_test.shape
# Out:
# ((182, 9), (61, 9))

# %%
X_train
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC   ISI  Classes  Region
# 97            29  74  19   0.1  75.8   3.6   2.1        0       0
# 141           31  72  14   0.2  60.2   3.8   0.8        0       1
# 192           40  31  15   0.0  94.2  22.5  16.6        1       1
# 68            32  60  18   0.3  77.1  11.3   2.2        0       0
# 119           32  47  14   0.7  77.5   7.1   1.8        0       0
# ..           ...  ..  ..   ...   ...   ...   ...      ...     ...
# 106           24  82  15   0.4  44.9   0.9   0.2        0       0
# 14            28  80  17   3.1  49.4   3.0   0.4        0       0
# 92            25  76  17   7.2  46.0   1.3   0.2        0       0
# 179           34  59  16   0.0  88.1  19.5   7.4        1       1
# 102           30  77  21   1.8  58.5   1.9   1.1        0       0
#
# [182 rows x 9 columns]

# %% [markdown]
# ## feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train_scaled=sc.fit_transform(X_train)
X_test_scaled =sc.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[-0.84284248,  0.78307967,  1.29972026, ..., -0.62963326,
#         -1.10431526, -0.98907071],
#        [-0.30175842,  0.64950844, -0.59874754, ..., -0.93058524,
#         -1.10431526,  1.01105006],
#        [ 2.13311985, -2.08870172, -0.21905398, ...,  2.7271388 ,
#          0.90553851,  1.01105006],
#        ...,
#        [-1.9250106 ,  0.9166509 ,  0.54033314, ..., -1.06948615,
#         -1.10431526, -0.98907071],
#        [ 0.50986767, -0.21870454,  0.16063958, ...,  0.5973248 ,
#          0.90553851,  1.01105006],
#        [-0.57230045,  0.98343651,  2.05910739, ..., -0.86113478,
#         -1.10431526, -0.98907071]])

# %% [markdown]
# ## box plot to understand the effect of  standard scaler

# %%
plt.close('all')
plt.subplots(figsize=(15,5))
plt.subplot(1,2,1)
sns.boxplot(data=X_train)
plt.title("X_train before Scaling")
plt.subplot(1,2,2)
sns.boxplot(data=X_train_scaled)
plt.title("X_train  After Scaling")
plt.show()

# %% [markdown]
# ## linear Regression Model

# %%
from sklearn.metrics import r2_score
from sklearn .linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
lr =LinearRegression()
lr .fit(X_train_scaled,Y_train)
y_pred = lr.predict(X_test_scaled)
mae = mean_absolute_error(Y_test,y_pred)
score = r2_score(Y_test,y_pred)
print("Mean absolute error",mae)
print("R2 Score",score)
plt.scatter(Y_test,y_pred)
plt.show()
# Out:
# Mean absolute error 0.5468236465249993
# R2 Score 0.9847657384266951

# %% [markdown]
# ## lasso regression

# %%
from sklearn.metrics import r2_score
from sklearn .linear_model import Lasso
from sklearn.metrics import mean_absolute_error
lasso =Lasso()
lasso .fit(X_train_scaled,Y_train)
y_pred = lasso.predict(X_test_scaled)
mae = mean_absolute_error(Y_test,y_pred)
score = r2_score(Y_test,y_pred)
print("Mean absolute error",mae)
print("R2 Score",score)
plt.scatter(Y_test,y_pred)
plt.show()
# Out:
# Mean absolute error 1.1331759949144085
# R2 Score 0.9492020263112388

# %%
from sklearn.linear_model import LassoCV
lassocv = LassoCV(cv=5)
lassocv.fit(X_train_scaled,Y_train)
# Out:
# LassoCV(cv=5)

# %%
y_pred = lassocv.predict(X_test_scaled)
plt.scatter(Y_test,y_pred)
mae = mean_absolute_error(Y_test,y_pred)
score = r2_score(Y_test,y_pred)
print("Mean absolute error",mae)
print("R2 Score",score)
plt.show()
# Out:
# Mean absolute error 0.6199701158263432
# R2 Score 0.9820946715928275

# %% [markdown]
# ## Ridge Regression

# %%
from sklearn.metrics import r2_score
from sklearn .linear_model import Ridge
from sklearn.metrics import mean_absolute_error
Ridge =Ridge()
Ridge .fit(X_train_scaled,Y_train)
y_pred = Ridge.predict(X_test_scaled)
mae = mean_absolute_error(Y_test,y_pred)
score = r2_score(Y_test,y_pred)
print("Mean absolute error",mae)
print("R2 Score",score)
plt.scatter(Y_test,y_pred)
plt.show()
# Out:
# Mean absolute error 0.5642305340105712
# R2 Score 0.9842993364555513

# %%
from sklearn.linear_model import RidgeCV
ridgecv = RidgeCV(cv =5)
ridgecv.fit(X_train_scaled,Y_train)
# Out:
# RidgeCV(cv=5)

# %%
Y_pred =ridgecv.predict(X_test_scaled)
plt.scatter(Y_test,Y_pred)
mae = mean_absolute_error(Y_test,y_pred)
score = r2_score(Y_test,y_pred)
print("Mean absolute error",mae)
print("R2 Score",score)
plt.show()
# Out:
# Mean absolute error 0.6199701158263432
# R2 Score 0.9820946715928275

# %% [markdown]
# ## Elastic net

# %%
from sklearn.metrics import r2_score
from sklearn .linear_model import ElasticNet
from sklearn.metrics import mean_absolute_error
ElasticNet =ElasticNet()
ElasticNet .fit(X_train_scaled,Y_train)
y_pred = ElasticNet.predict(X_test_scaled)
mae = mean_absolute_error(Y_test,y_pred)
score = r2_score(Y_test,y_pred)
print("Mean absolute error",mae)
print("R2 Score",score)
plt.scatter(Y_test,y_pred)
plt.show()
# Out:
# Mean absolute error 1.8822353634896
# R2 Score 0.8753460589519703

# %%
from sklearn.linear_model import ElasticNetCV
elasticcv = ElasticNetCV(cv =5)
elasticcv.fit(X_train_scaled,Y_train)
# Out:
# ElasticNetCV(cv=5)

# %%
Y_pred =elasticcv.predict(X_test_scaled)
plt.scatter(Y_test,Y_pred)
mae = mean_absolute_error(Y_test,y_pred)
score = r2_score(Y_test,y_pred)
print("Mean absolute error",mae)
print("R2 Score",score)
plt.show()
# Out:
# Mean absolute error 0.6199701158263432
# R2 Score 0.9820946715928275

# %%
residual = Y_test-y_pred
residual
# Out:
# 24     0.225094
# 6     -0.483125
# 152    0.756765
# 232   -0.926434
# 238   -0.287158
#          ...
# 162   -0.190564
# 178   -0.087373
# 224    0.055440
# 230    0.960088
# 154   -0.030341
# Name: FWI, Length: 61, dtype: float64

# %%
sns.displot(residual, kind='kde')
plt.xlabel('index_price',fontsize=14)
plt.show()

# %%
## scatter plot with respect to predicted and residual value
plt.scatter(y_pred,residual,color='red')
plt.show()

# %% [markdown]
# ## pickle
# # it used for serializing and deserializing a python object structure.

# %%
sc
# Out:
# StandardScaler()

# %%
Ridge
# Out:
# Ridge()

# %%
## pickle the machine learning model 
import pickle
pickle.dump(sc,open('scaler.pkl','wb'))
pickle.dump(Ridge,open('Ridge.pkl','wb'))

# %%
model=pickle.load(open('elastic.pkl','rb'))

# %%
model.predict(X_test)
# Out:
# c:\Users\KIIT\anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but ElasticNetCV was fitted without feature names
#   warnings.warn(
# array([ 28.91686019,  17.63371318, -18.6881757 ,  32.83916988,
#         30.0750944 ,   4.67783191, -17.2431141 ,  43.33543278,
#         -4.40217242,   8.09173819, -14.72944372,  99.27663908,
#         41.82570797, 113.37414214, 117.94468724,  -3.59671225,
#         12.19225499, -21.33274385,  20.34535196,  -0.78006928,
#        -18.76741225, -21.31825151,   4.82932386, -21.25229363,
#        107.223837  ,  15.6748172 ,  16.01425127,  47.12791175,
#        -21.40434232,  37.43880127,  18.81431411, -18.25870316,
#         46.48880778,  97.41699125, -15.59271841, -13.31800473,
#        -22.05427355,  33.14170846, -17.0127832 , -17.10062784,
#         28.73757476, -11.3455193 ,  36.78070201, -23.93664499,
#         82.53520891,  31.89616779,  46.8451867 ,  -6.21881998,
# ...
